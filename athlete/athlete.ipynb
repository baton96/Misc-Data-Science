# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('athlete.csv') # ['Sex', 'Age', 'Height', 'Weight', 'NOC', 'Year', 'Season', 'Sport', 'Medal']
df = df[(df.Sport=='Gymnastics') | (df.Sport=='Weightlifting')]

# %%
sns.displot(df, x="Weight", col="Sport", bins=10, hue="Sex")
sns.displot(df, x="Weight", hue="Sport", bins=10, col="Sex")
